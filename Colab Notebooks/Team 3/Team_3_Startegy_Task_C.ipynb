# %% [markdown]
# ## 🏬 Strategy Task C: Shortlisting 10 New Hypermarkets for OC&Grocery
#
# ### 🧭 Objective
# OC&Grocery is rapidly expanding its store portfolio and plans to open **10 new hypermarkets** in the coming year. Your team at OC&C has been asked to **identify the top 10 locations** with the highest potential for success.
#
# ---
#
# ### 🧠 Your Role
#
# You are responsible for helping OC&Grocery **shortlist the 10 best-performing new store locations**, backed by data and strategic insight. Your analysis should aim to:
#
# - Understand **what drives hypermarket success**
# - Identify **high-potential locations** from a test set
# - Recommend an **optimal store format** for each shortlisted location
#
# ---
#
# ### 🧱 Task Structure
#
# #### 📊 Hypermarket Analysis
# - What **location factors** (e.g., demographics, competition, foot traffic) correlate with high-performing hypermarkets?
# - What **differentiates** high vs. low-performing hypermarkets in the existing network?
#
# #### 🎯 Store Selection
# - From the provided test set of candidate locations, which **10 stores** show the **highest revenue potential**?
#
# #### 🧩 Store Strategy
# - What is the **best store format** for these new locations?
#   Should they be standard hypermarkets or tailored to local conditions?
#
# ---
#
# ### 📌 Key Questions to Consider
# - Which **locations** are driving sales performance, and why?
# - Are there **patterns** (e.g., region, population density) that should guide expansion?
# - How can we ensure the new stores align with **OC&Grocery’s broader strategy**?
#
# Your final shortlist should be **data-driven** and backed by clear logic on **location selection and store design**.

# %%
# Your code here!!
