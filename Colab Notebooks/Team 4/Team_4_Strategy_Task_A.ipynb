# %% [markdown]
# ## 🌿 Strategy Task A: Designing OC&Grocery’s 5-Year Organic Growth Strategy
#
# ### 🧭 Objective
# OC&Grocery has refreshed their overall strategy, and one of the new strategic pillars is to **become a national leader in organic products**. However, **there is currently no structured strategy** on how to approach the **supply of organic products** to stores.
#
# Your team at OC&C has been asked to develop an **effective and tailored strategy** for rolling out organic products across their portfolio of stores.
#
# ---
#
# ### 🧠 Key Responsibilities
#
# You are part of the OC&C team helping to design OC&Grocery’s **5-Year Organic Strategy**. Your job is to:
#
# - Understand **how organic performance varies** by store characteristics
# - Identify the factors that influence success in selling organic products
# - Develop a strategy that is **not one-size-fits-all** but is tailored to different store types
#
# Things to consider:
# - 🏬 Store size
# - 📍 Location
# - 🛒 Store type (e.g. supermarket vs hypermarket)
# - ...and more
#
# ---
#
# ### 🧱 Output Structure
#
# #### 🔍 Current State of Affairs
# - What is the current **importance of organic products** to OC&Grocery?
# - Is there an existing **strategy for how organics are distributed** to stores?
#
# #### 📈 Store Success Drivers
# - Is there a **relationship between store success and organic offerings**?
# - Are there **diminishing returns** from increasing organic share?
#   Is this effect consistent across all store types?
#
# #### 🧩 Strategy Design
# - What is the **optimal organic product share** in:
#   - An average supermarket?
#   - An average hypermarket?
# - Can we **unpick this by store type**?
#
# ---
#
# ### 📝 Final Goal
# Build a **structured, insight-driven strategy** that enables OC&Grocery to efficiently and effectively expand its leadership in organic grocery—**tailored by store characteristics**.

# %%
# Your code here!!
